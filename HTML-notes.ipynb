# %% [markdown]
# # HTML Notes
# ***

# %% [markdown]
# ## 1. HTML Structure

# %% [markdown]
# `HTML` is the standard language for creating web pages. It uses a series of elements represent by tags like this:
# ```
# <body>
#     <p>This is a paragraph</p>
# </body>
# ```

# %% [markdown]
# 1. .
# 2. ..
# 3. ...

# %% [markdown]
# *italic*

# %% [markdown]
# __bold text__

# %% [markdown]
# .[AI Colors Image] (https://cdn.pixabay.com/photo/2023/01/26/22/14/ai-generated-7747165_640.jpg)

# %%
from IPython.display import Image
Image(filename='dog.jpg')

# %% [markdown]
# ## Headings

# %% [markdown]
# ```
# <h1>Main Heading</h1>
# <h2>Subheading</h2>
# <h3>Sub-Subheading</h3>
# ```

# %% [markdown]
# Heading Example:
# ```
# <h1>Fruits</h1>
# <ul>
#     <li>Orange</li>
#     <li>Apples</li>
# </ul>
# ```
